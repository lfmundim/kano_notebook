# %%
import pandas as pd
import importlib
from tabulate import tabulate

# %% [markdown]
# # Set up
# Save your `.csv` file with the responses from your forms on the same folder as this file.
#
# This project assumes your functional responses and dysfunctional responses are back to back, in this order.
#
# Configure below the text values for the responses matching each Kano response

# %%
filename = 'raw.csv'

# %% [markdown]
# Now what pairs return each category?

# %% [markdown]
# Now don't change anything else, just run the rest of the Notebook and get your results :)

# %%
import kano_analysis
import metrics
importlib.reload(kano_analysis)
importlib.reload(metrics)
from kano_analysis import apply_kano_categorization
from metrics import generate_feature_percentages, generate_feature_counts, generate_highest_category_table
from tabulate import tabulate

if __name__ == "__main__":
    # Load data
    df = pd.read_csv(filename)

    # Apply Kano analysis
    df_kano, scores = apply_kano_categorization(df)

    # Generate percentages and counts
    feature_percentages = generate_feature_percentages(df_kano)
    feature_counts = generate_feature_counts(df_kano)
    highest_category_table = generate_highest_category_table(feature_percentages)

    # Save results
    df_kano.to_csv('kano_analysis_results.csv', index=False)
    feature_percentages.to_csv('kano_feature_percentages.csv', index=True)
    feature_counts.to_csv('kano_feature_counts.csv', index=True)
    scores.to_csv('kano_average_scores.csv', index=False)

    # Display results
    print("\nFeature-wise average functional and dysfunctional scores:")
    print(tabulate(scores, headers='keys', tablefmt='fancy_grid', showindex=False))

    print("\nFeature-wise absolute counts of Kano categories:")
    print(tabulate(feature_counts, headers='keys', tablefmt='fancy_grid', showindex=True))

    print("\nFeature-wise percentages of Kano categories:")
    print(tabulate(feature_percentages, headers='keys', tablefmt='fancy_grid', showindex=True))

    print("\nTable of Features with the Highest Percentile and Corresponding Category:")
    print(tabulate(highest_category_table, headers='keys', tablefmt='fancy_grid', showindex=False))
# Out:
# {('Like', 'Tolerate'): 'Atrativo', ('Like', 'Neutral'): 'Atrativo', ('Like', 'Expect'): 'Atrativo', ('Like', 'Dislike'): 'Desempenho', ('Expect', 'Dislike'): 'Básico', ('Neutral', 'Dislike'): 'Básico', ('Tolerate', 'Dislike'): 'Básico', ('Dislike', 'Like'): 'Reverso', ('Dislike', 'Tolerate'): 'Reverso', ('Dislike', 'Neutral'): 'Reverso', ('Dislike', 'Expect'): 'Reverso', ('Like', 'Like'): 'Questionável', ('Dislike', 'Dislike'): 'Questionável'}
#
# Feature-wise average functional and dysfunctional scores:
# ╒═══════════╤════════════════════════╤═══════════════════════════╕
# │ Feature   │   Av. Functional Score │   Av. Dysfunctional Score │
# ╞═══════════╪════════════════════════╪═══════════════════════════╡
# │ 1a        │                   2.57 │                      2.18 │
# ├───────────┼────────────────────────┼───────────────────────────┤
# │ 2a        │                   2.89 │                      2.66 │
# ├───────────┼────────────────────────┼───────────────────────────┤
# ...
